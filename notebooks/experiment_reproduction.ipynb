# %% [markdown]
# # Experiment Reproduction
#
# This notebook contains code to reproduce experiments in our paper, [Sparse Autoencoders for Hypothesis Generation](https://arxiv.org/abs/2502.04382).
#
# Currently, it includes the three real-world datasets we study: Headlines (predicting online engagement levels with news headlines), Yelp (predicting restaurant rating from review text), and Congress (predicting party affiliation from Congressional speech excerpts).
#
# Important notes:
# 1. Our processed, documented versions of the data can be found on HuggingFace: [https://huggingface.co/datasets/rmovva/HypotheSAEs](https://huggingface.co/datasets/rmovva/HypotheSAEs).
# 2. There is some run-to-run variance due to stochasticity in neuron interpretation, which uses an LLM (default temperature 0.7). This may explain differences from results in the paper.
# 3. There are multiple possible strategies when sampling texts to interpret an SAE neuron:
#     - The default version of the code (i.e., if you use the quickstart function `generate_hypotheses()`) interprets neurons by using the top-10 activating examples.
#     - In contrast, for the paper we used a random sample of 10 examples from the top decile (or quintile, for Headlines) of positive activations (by passing in `sample_percentile_bins` as the sampling function). This sampling strategy produces less specific concepts, so they occur more frequently and are therefore more predictive.
#     - For most use cases, we expect that more specific concepts are more useful, which is why the default version of the code uses the absolute top-activating examples. However, if you would like less specific concepts, you can vary the sampling strategy by implementing something similar to the code in this notebook.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd

os.environ['OPENAI_KEY_SAE'] = '...' # Replace with your OpenAI API key, or with another environment variable (e.g. os.environ['OPENAI_API_KEY'])

from hypothesaes.quickstart import train_sae, generate_hypotheses, evaluate_hypotheses

from hypothesaes.embedding import get_openai_embeddings
from hypothesaes.sae import get_multiple_sae_activations
from hypothesaes.select_neurons import select_neurons
from hypothesaes.interpret_neurons import NeuronInterpreter, InterpretConfig, ScoringConfig, SamplingConfig, sample_percentile_bins
from hypothesaes.annotate import annotate_texts_with_concepts
from hypothesaes.evaluation import score_hypotheses

base_dir = "/share/pierson/raj/hypothesis-generation-data/"

# %% [markdown]
# ## Headlines
#
# Note that Headlines requires some special handling because it is a pairwise dataset.
# Each example contains two headlines, A and B, and a binary label: 1 if headline A received higher clicks than B, 0 otherwise. A and B were randomly shuffled, so the label is approximately balanced.
#
# We apply HypotheSAEs as follows:
# 1. Train SAE on all unique headlines in the train set.
# 2. Compute $Z_A$, an $N \times M$ activation matrix for all headline A's; similarly compute $Z_B$.
# 3. Compute $Z_{\Delta} = Z_A - Z_B$, which represents how much more (or less) each feature activates in headline A compared to B.
# 4. Select 20 neurons using L1 logistic regression on $Z_{\Delta}$.
# 5. Interpret selected neurons by sampling from the texts originally used to train the SAE.
#
# For evaluation:
# 1. Compute $H_A$, an $N \times 20$ binary matrix of hypothesis annotations for all headlines A, and $H_B$ similarly.
# 2. Compute $H_{\Delta} = H_A - H_B$, and regress the label on this difference. Note that $H_{\Delta}$ can take on values in $\{-1, 0, 1\}$, which we account for in `src.evaluation.compute_hypothesis_separation_scores`.

# %%
DATASET_NAME = "headlines"
EMBEDDER = "text-embedding-3-small"
CACHE_NAME = f"{DATASET_NAME}_{EMBEDDER}"

label_col = "label_pairwise"
train_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "headline_pairs_train.json"), lines=True)
val_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "headline_pairs_validation_v2.json"), lines=True)

train_labels = train_df[label_col].values

unique_train_texts = np.unique(train_df["headline_A"].tolist() + train_df["headline_B"].tolist()).tolist()
unique_val_texts = np.unique(val_df["headline_A"].tolist() + val_df["headline_B"].tolist()).tolist()

text2embedding = get_openai_embeddings(unique_train_texts + unique_val_texts, model=EMBEDDER, cache_name=CACHE_NAME)

train_embeddings = np.stack([text2embedding[text] for text in unique_train_texts])
val_embeddings = np.stack([text2embedding[text] for text in unique_val_texts])
# Out:
# Loading embedding chunks:   0%|          | 0/1 [00:00<?, ?it/s]
# Loaded 16468 embeddings in 2.8s

# %%
checkpoint_dir = f"./checkpoints/{CACHE_NAME}"
sae_256_8 = train_sae(embeddings=train_embeddings, M=256, K=8, checkpoint_dir=checkpoint_dir, val_embeddings=val_embeddings, n_epochs=200, patience=5)
sae_32_4 = train_sae(embeddings=train_embeddings, M=32, K=4, checkpoint_dir=checkpoint_dir, val_embeddings=val_embeddings, n_epochs=200, patience=5)

sae_list = [sae_256_8, sae_32_4]

unique_train_activations, neuron_source_sae_info = get_multiple_sae_activations(sae_list, train_embeddings, return_neuron_source_info=True)

headline_A_train = np.stack([text2embedding[text] for text in train_df["headline_A"].tolist()])
headline_B_train = np.stack([text2embedding[text] for text in train_df["headline_B"].tolist()])

Z_A = get_multiple_sae_activations(sae_list, headline_A_train)
Z_B = get_multiple_sae_activations(sae_list, headline_B_train)
Z_delta = Z_A - Z_B

selected_neurons, scores = select_neurons(
    activations=Z_delta,
    target=train_labels,
    n_select=20,
    method="lasso",
    classification=True,
    verbose=True,
)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping triggered after 79 epochs
# Saved model to ./checkpoints/headlines_text-embedding-3-small/SAE_M=256_K=8.pt
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping triggered after 63 epochs
# Saved model to ./checkpoints/headlines_text-embedding-3-small/SAE_M=32_K=4.pt
# LASSO iteration   L1 Alpha # Features   Time (s)
# ----------------------------------------
#        0   1.00e-01        287       1.75
#        1   3.16e+01        199       0.50
#        2   5.62e+02          2       0.21
#        3   1.33e+02         74       0.28
#        4   2.74e+02         24       0.20
#        5   3.92e+02         12       0.18
#        6   3.28e+02         18       0.21
#        7   3.00e+02         21       0.17
#        8   3.13e+02         20       0.19
#
# Found alpha=3.13e+02 yielding exactly 20 features
# Total search time: 3.70s

# %%
interpreter = NeuronInterpreter(
    interpreter_model="gpt-4o",
    annotator_model="gpt-4o-mini",
    n_workers_annotation=50,
    cache_name=CACHE_NAME,
)

interpretation_sampling_config = SamplingConfig(
    function=sample_percentile_bins,
    n_examples=20,
    extra_kwargs={
        "high_percentile": (80, 100),
        "low_percentile": None, # Randomly samples from zero-activating examples
    },
)

interpret_config = InterpretConfig(
    sampling=interpretation_sampling_config,
    n_candidates=5,
    task_specific_instructions="""All of the texts are digital news headlines.
Features should describe specific characteristics in the headline texts. Example features may include:
- "explicitly mentions climate change or another environmental issue"
- "asks the reader a rhetorical question\"""",
)

interpretations = interpreter.interpret_neurons(
    texts=unique_train_texts,
    activations=unique_train_activations,
    neuron_indices=selected_neurons,
    config=interpret_config,
)
# Out:
# Generating 5 interpretation(s) per neuron:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
scoring_config = ScoringConfig(
    n_examples=200,
    sampling_function=sample_percentile_bins,
    sampling_kwargs={
        "high_percentile": (80, 100),
        "low_percentile": None, # Randomly samples from zero-activating examples
    },
)

all_metrics = interpreter.score_interpretations(
    texts=unique_train_texts,
    activations=unique_train_activations,
    interpretations=interpretations,
    config=scoring_config,
)

results = []
for neuron_idx, fidelity_scores in all_metrics.items():
    best_interp = max(interpretations[neuron_idx], key=lambda interp: fidelity_scores[interp]['f1'])
    results.append({
        'neuron_idx': neuron_idx,
        'source_sae': neuron_source_sae_info[neuron_idx],
        'target_lasso_coef': scores[selected_neurons.index(neuron_idx)],
        'interpretation': best_interp,
        'f1_fidelity_score': fidelity_scores[best_interp]['f1'],
    })

hypothesis_df = pd.DataFrame(results)
pd.set_option('display.max_colwidth', None)
display(hypothesis_df.sort_values(by='target_lasso_coef', ascending=False))
pd.reset_option('display.max_colwidth')
# Out:
# Warning: There are less than 100 examples in (80, 100) for neuron 6; using 78 instead
# Found 55 cached items; annotating 19835 uncached items
# Scoring neuron interpretation fidelity (20 neurons; 5 candidate interps per neuron; 200 examples to score each…
#     neuron_idx source_sae  target_lasso_coef  \
# 1          269    (32, 4)           0.099923
# 4          279    (32, 4)           0.056853
# 5          163   (256, 8)           0.055063
# 6          126   (256, 8)           0.054179
# 7            6   (256, 8)           0.053329
# 8          268    (32, 4)           0.044655
# 11         283    (32, 4)           0.031996
# 14         281    (32, 4)           0.017388
# 15         259    (32, 4)           0.011012
# 16         277    (32, 4)           0.010464
# 18         209   (256, 8)           0.004956
# 19         132   (256, 8)          -0.003128
# 17         166   (256, 8)          -0.005192
# 13         117   (256, 8)          -0.018370
# 12         276    (32, 4)          -0.027952
# 10         256    (32, 4)          -0.032606
# 9          270    (32, 4)          -0.034680
# 3          275    (32, 4)          -0.071543
# 2          274    (32, 4)          -0.087818
# 0          123   (256, 8)          -0.139616
#
#                                                                                                                                                                               interpretation  \
# 1                                                                                                                                mentions a video or visual media explicitly in the headline
# 4                                                                                                                              explicitly implies the revelation of a hidden truth or secret
# 5                                                         contains words or phrases that describe something as 'awful', 'horrible', 'dangerous', 'painful', or similarly negative adjectives
# 6   contains phrases that challenge the reader's assumptions or expectations (e.g., 'you might not think', 'wait till you see', 'you probably don't think', 'might change the way you look')
# 7                                                                                                         mentions a personal or emotional event followed by an unexpected or dramatic twist
# 8                                                                                                               mentions interpersonal conflict or negative interactions between individuals
# 11                                                                                                                           mentions a specific male individual using 'he', 'his', or 'him'
# 14                                                                                                                               focuses on a woman or uses female pronouns (e.g., she, her)
# 15                                                                                                                            mentions body image, appearance, or how people view themselves
# 16                                                               uses emotional language to describe personal reactions or feelings (e.g., crying, shouting, feeling sick, feeling strength)
# 18                                                                                                                             mentions a specific duration of time (e.g., seconds, minutes)
# 19                                                                                                                   uses a conversational tone with rhetorical questions or casual phrasing
# 17                                                                                                                                  mentions protests, activism, or collective social action
# 13                                                                                                       contains language that emphasizes aspirations, personal growth, or achieving dreams
# 12                                                                                                                               mentions inspiring or extraordinary achievements or moments
# 10                                                                                                     uses uplifting or inspirational language to convey a positive or motivational message
# 9                                                                                                                                  asks a rhetorical question about societal or moral issues
# 3                                                                                                                     mentions an environmental issue or action related to saving the planet
# 2                                                                                                                                 mentions a positive or hopeful societal change or solution
# 0                                                                                                                                                          headline is phrased as a question
#
#     f1_fidelity_score
# 1            0.891000
# 4            0.844260
# 5            0.874743
# 6            0.691200
# 7            0.903674
# 8            0.825663
# 11           0.826941
# 14           0.989899
# 15           0.642207
# 16           0.883616
# 18           0.969897
# 19           0.573793
# 17           0.884494
# 13           0.795828
# 12           0.711111
# 10           0.546000
# 9            0.744161
# 3            0.863636
# 2            0.791304
# 0            0.941799

# %%
holdout_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "headline_pairs_holdout_v2.json"), lines=True)

headline_A_holdout = holdout_df["headline_A"].tolist()
headline_B_holdout = holdout_df["headline_B"].tolist()
labels_holdout = holdout_df[label_col].values

hypotheses = hypothesis_df["interpretation"].tolist()

headline_A_annotations = annotate_texts_with_concepts(
    texts=headline_A_holdout,
    concepts=hypotheses,
    cache_name=CACHE_NAME,
)

headline_B_annotations = annotate_texts_with_concepts(
    texts=headline_B_holdout,
    concepts=hypotheses,
    cache_name=CACHE_NAME,
)

delta_annots = {key : headline_A_annotations[key] - headline_B_annotations[key] for key in headline_A_annotations.keys()}

metrics, evaluation_df = score_hypotheses(
    hypothesis_annotations=delta_annots,
    y_true=labels_holdout,
    classification=True
)

pd.set_option('display.max_colwidth', None)
display(evaluation_df.sort_values(by='separation_score', ascending=False).round(4))
pd.reset_option('display.max_colwidth')

print(f"AUC: {metrics['auroc']:.3f}")
print(f"Significant hypotheses: {metrics['Significant'][0]}/{metrics['Significant'][1]} " 
      f"(p < {metrics['Significant'][2]:.3e})")
# Out:
# Found 0 cached items; annotating 87140 uncached items
# Annotating:   0%|          | 0/87140 [00:00<?, ?it/s]
# Found 5040 cached items; annotating 82100 uncached items
# Annotating:   0%|          | 0/82100 [00:00<?, ?it/s]
# Optimization terminated successfully.
#          Current function value: 0.631850
#          Iterations 5
#                                                                                                                                                                                   hypothesis  \
# 7                                                                                                         mentions a personal or emotional event followed by an unexpected or dramatic twist
# 4                                                                                                                              explicitly implies the revelation of a hidden truth or secret
# 18                                                                                                                             mentions a specific duration of time (e.g., seconds, minutes)
# 8                                                                                                               mentions interpersonal conflict or negative interactions between individuals
# 14                                                                                                                               focuses on a woman or uses female pronouns (e.g., she, her)
# 11                                                                                                                           mentions a specific male individual using 'he', 'his', or 'him'
# 1                                                                                                                                mentions a video or visual media explicitly in the headline
# 5                                                         contains words or phrases that describe something as 'awful', 'horrible', 'dangerous', 'painful', or similarly negative adjectives
# 6   contains phrases that challenge the reader's assumptions or expectations (e.g., 'you might not think', 'wait till you see', 'you probably don't think', 'might change the way you look')
# 15                                                                                                                            mentions body image, appearance, or how people view themselves
# 16                                                               uses emotional language to describe personal reactions or feelings (e.g., crying, shouting, feeling sick, feeling strength)
# 12                                                                                                                               mentions inspiring or extraordinary achievements or moments
# 19                                                                                                                   uses a conversational tone with rhetorical questions or casual phrasing
# 9                                                                                                                                  asks a rhetorical question about societal or moral issues
# 10                                                                                                     uses uplifting or inspirational language to convey a positive or motivational message
# 17                                                                                                                                  mentions protests, activism, or collective social action
# 0                                                                                                                                                          headline is phrased as a question
# 13                                                                                                       contains language that emphasizes aspirations, personal growth, or achieving dreams
# 2                                                                                                                                 mentions a positive or hopeful societal change or solution
# 3                                                                                                                     mentions an environmental issue or action related to saving the planet
#
#     separation_score  separation_pval  regression_coef  regression_pval  \
# 7             0.1812              0.0           0.4397           0.0000
# 4             0.1654              0.0           0.5535           0.0000
# 18            0.1449              0.0           0.5710           0.0001
# 8             0.1316              0.0           0.3016           0.0002
# 14            0.1197              0.0           0.3201           0.0010
# 11            0.1047              0.0           0.1617           0.1673
# 1             0.1034              0.0           0.4749           0.0000
# 5             0.0922              0.0           0.1365           0.0867
# 6             0.0859              0.0           0.3351           0.0000
# 15            0.0738              0.0           0.1708           0.2466
# 16            0.0554              0.0          -0.0058           0.9415
# 12            0.0395              0.0           0.4587           0.0000
# 19           -0.0240              0.0          -0.0775           0.1796
# 9            -0.0669              0.0          -0.2915           0.0001
# 10           -0.0819              0.0          -0.1143           0.2043
# 17           -0.1117              0.0          -0.5542           0.0000
# 0            -0.1130              0.0          -0.2986           0.0000
# 13           -0.1390              0.0          -0.5038           0.0000
# 2            -0.1434              0.0          -0.4961           0.0000
# 3            -0.1584              0.0          -0.6157           0.0001
#
#     feature_prevalence
# 7               0.2031
# 4               0.2931
# 18              0.0521
# 8               0.1923
# 14              0.1187
# 11              0.0842
# 1               0.1047
# 5               0.1958
# 6               0.4044
# 15              0.0503
# 16              0.2286
# 12              0.1983
# 19              0.3987
# 9               0.3078
# 10              0.1974
# 17              0.0643
# 0               0.2862
# 13              0.1074
# 2               0.1809
# 3               0.0461
# AUC: 0.695
# Significant hypotheses: 14/20 (p < 5.000e-03)

# %% [markdown]
# ## Yelp

# %%
DATASET_NAME = "yelp"
EMBEDDER = "text-embedding-3-small"
CACHE_NAME = f"{DATASET_NAME}_{EMBEDDER}"

text_col = "text"
label_col = "stars"
train_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "train-200K.json"), lines=True)
val_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "val-10K.json"), lines=True)

train_texts = train_df[text_col].tolist()
val_texts = val_df[text_col].tolist()

train_labels = train_df[label_col].values

text2embedding = get_openai_embeddings(train_texts + val_texts, model=EMBEDDER, cache_name=CACHE_NAME)

train_embeddings = np.stack([text2embedding[text] for text in train_texts])
val_embeddings = np.stack([text2embedding[text] for text in val_texts])
# Out:
# Loading embedding chunks:   0%|          | 0/5 [00:00<?, ?it/s]
# Loaded 209977 embeddings in 18.0s

# %%
checkpoint_dir = f"./checkpoints/{CACHE_NAME}"
sae_1024_32 = train_sae(embeddings=train_embeddings, M=1024, K=32, checkpoint_dir=checkpoint_dir, val_embeddings=val_embeddings)

activations = sae_1024_32.get_activations(train_embeddings)

selected_neurons, scores = select_neurons(
    activations=activations,
    target=train_labels,
    n_select=20,
    method="lasso",
    classification=False,
    verbose=True,
)
# Out:
# Loaded model from ./checkpoints/yelp_text-embedding-3-small/SAE_M=1024_K=32.pt
# LASSO iteration   L1 Alpha # Features   Time (s)
# ----------------------------------------
#        0   1.00e-01          5       3.81
#        1   3.16e-04        913      10.00
#        2   5.62e-03        197       4.94
#        3   2.37e-02         45       5.64
#        4   4.87e-02         12       7.13
#        5   3.40e-02         26       8.33
#        6   4.07e-02         19       8.10
#        7   3.72e-02         21       8.11
#        8   3.89e-02         19       8.11
#        9   3.80e-02         19       8.15
#       10   3.76e-02         19       8.14
#       11   3.74e-02         21       8.17
#       12   3.75e-02         20       8.21
#
# Found alpha=3.75e-02 yielding exactly 20 features
# Total search time: 96.93s

# %%
interpreter = NeuronInterpreter(
    interpreter_model="gpt-4o",
    annotator_model="gpt-4o-mini",
    n_workers_annotation=50,
    cache_name=CACHE_NAME,
)

interpretation_sampling_config = SamplingConfig(
    function=sample_percentile_bins,
    n_examples=20,
    extra_kwargs={
        "high_percentile": (90, 100),
        "low_percentile": None, # Randomly samples from zero-activating examples
    },
)

interpret_config = InterpretConfig(
    sampling=interpretation_sampling_config,
    n_candidates=3,
    task_specific_instructions = """All of the texts are reviews of restaurants on Yelp.
Features should describe a specific aspect of the review. For example:
- "mentions long wait times to receive service"
- "praises how a dish was cooked, with phrases like 'perfect medium-rare'\""""
)

interpretations = interpreter.interpret_neurons(
    texts=train_texts,
    activations=activations,
    neuron_indices=selected_neurons,
    config=interpret_config,
)

scoring_config = ScoringConfig(
    n_examples=200,
    sampling_function=sample_percentile_bins,
    sampling_kwargs={
        "high_percentile": (90, 100),
        "low_percentile": None, # Randomly samples from zero-activating examples
    },
)

all_metrics = interpreter.score_interpretations(
    texts=train_texts,
    activations=activations,
    interpretations=interpretations,
    config=scoring_config,
)
# Out:
# Generating 3 interpretation(s) per neuron:   0%|          | 0/60 [00:00<?, ?it/s]
# Found 2 cached items; annotating 11998 uncached items
# Scoring neuron interpretation fidelity (20 neurons; 3 candidate interps per neuron; 200 examples to score each…

# %%
results = []
for neuron_idx, fidelity_scores in all_metrics.items():
    best_interp = max(interpretations[neuron_idx], key=lambda interp: fidelity_scores[interp]['f1'])
    results.append({
        'neuron_idx': neuron_idx,
        'target_lasso_coef': scores[selected_neurons.index(neuron_idx)],
        'interpretation': best_interp,
        'f1_fidelity_score': fidelity_scores[best_interp]['f1'],
    })

interpretation_df = pd.DataFrame(results)
pd.set_option('display.max_colwidth', None)
display(interpretation_df.sort_values(by='target_lasso_coef', ascending=False))
pd.reset_option('display.max_colwidth')
# Out:
#     neuron_idx  target_lasso_coef  \
# 2          767           0.077037
# 7          313           0.023009
# 10           4           0.009572
# 14         554           0.005992
# 19         262           0.000053
# 18          21          -0.002484
# 17         840          -0.003030
# 16         763          -0.003443
# 15         864          -0.003551
# 13         941          -0.006590
# 12         122          -0.008083
# 11         900          -0.008381
# 9          329          -0.012144
# 8          305          -0.013403
# 6          340          -0.025866
# 5          380          -0.041503
# 4          158          -0.050918
# 3          412          -0.072424
# 1          641          -0.078028
# 0          914          -1.114304
#
#                                                                                                                                                    interpretation  \
# 2                  describes food as exceptionally flavorful or perfectly prepared, using superlatives like 'amazing', 'perfect', 'incredible', or 'unbelievable'
# 7                                                                                  uses enthusiastic language to describe the taste or quality of specific dishes
# 10                                                                   explicitly describes something as 'the best' or 'best [specific item]' in a positive context
# 14  expresses extreme enthusiasm or excitement about the food, using repeated words or exaggerated phrases (e.g., 'love love love', 'to die for', 'drool worthy')
# 19        uses superlative language to describe the restaurant as the best in a specific category (e.g., 'best lobster roll', 'best bakery', 'best cheesesteaks')
# 18       mentions dissatisfaction with specific aspects of a venue or service, often with detailed complaints about cleanliness, maintenance, or customer service
# 17                                                    describes safety concerns or warnings, such as issues with spicy food, unsafe bathrooms, or drink tampering
# 16                        mentions negative or critical commentary about the restaurant's atmosphere, food quality, or service in a sarcastic or exaggerated tone
# 15                                                                    mentions issues or complaints about restaurant policies, services, or operational practices
# 13                                                                mentions experiences of food causing illness, such as food poisoning, stomach pain, or vomiting
# 12                                                             mentions lack of availability or inadequacy of food, beverages, or services advertised or expected
# 11                                                                mentions unhygienic conditions in the restaurant, such as filth, grease, or lack of cleanliness
# 9                                                                                                          mentions long wait times for seating, food, or service
# 8                                                                                                           mentions high or unexpected prices for food or drinks
# 6                                                          complains about repeated service errors or unresolved issues despite multiple attempts to address them
# 5                                                        mentions issues with incorrect or missing food orders, often involving unhelpful or rude staff responses
# 4                                                                                       mentions dissatisfaction with restaurant policies or management practices
# 3                                                                                                  mentions affordability or reasonable pricing of food or drinks
# 1                                                                                     mentions that the food is mediocre or has flaws in preparation or freshness
# 0                                                                                                                   complains about poor or rude customer service
#
#     f1_fidelity_score
# 2            0.787975
# 7            0.667857
# 10           0.963731
# 14           0.684088
# 19           0.929032
# 18           0.572773
# 17           0.657534
# 16           0.643101
# 15           0.587288
# 13           0.979592
# 12           0.802099
# 11           0.984772
# 9            0.964974
# 8            0.813214
# 6            0.897222
# 5            0.819512
# 4            0.859886
# 3            0.497521
# 1            0.826988
# 0            0.979592

# %%
np.random.seed(42)
holdout_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "holdout-50K.json"), lines=True)
holdout_sample_size = 10000
holdout_indices = np.random.choice(len(holdout_df), size=holdout_sample_size, replace=False)
holdout_sample = holdout_df.iloc[holdout_indices]

holdout_texts = holdout_sample[text_col].tolist()
holdout_labels = holdout_sample[label_col].values

metrics, hypothesis_df = evaluate_hypotheses(
    hypotheses_df=interpretation_df,
    texts=holdout_texts,
    labels=holdout_labels,
    cache_name=CACHE_NAME,
    classification=False,
    n_workers_annotation=50,
)

pd.set_option('display.max_colwidth', None)
display(hypothesis_df.round(3).sort_values(by='separation_score', ascending=False))
pd.reset_option('display.max_colwidth')

print(f"R^2: {metrics['r2']:.3f}")
print(f"Significant hypotheses: {metrics['Significant'][0]}/{metrics['Significant'][1]} " 
      f"(p < {metrics['Significant'][2]:.3e})")
# Out:
# Step 1: Annotating texts with 20 hypotheses
# Found 0 cached items; annotating 200000 uncached items
# Annotating:   0%|          | 0/200000 [00:00<?, ?it/s]
# Step 2: Computing predictiveness of hypothesis annotations
#                                                                                                                                                        hypothesis  \
# 7                                                                                  uses enthusiastic language to describe the taste or quality of specific dishes
# 14  expresses extreme enthusiasm or excitement about the food, using repeated words or exaggerated phrases (e.g., 'love love love', 'to die for', 'drool worthy')
# 2                  describes food as exceptionally flavorful or perfectly prepared, using superlatives like 'amazing', 'perfect', 'incredible', or 'unbelievable'
# 10                                                                   explicitly describes something as 'the best' or 'best [specific item]' in a positive context
# 19        uses superlative language to describe the restaurant as the best in a specific category (e.g., 'best lobster roll', 'best bakery', 'best cheesesteaks')
# 3                                                                                                  mentions affordability or reasonable pricing of food or drinks
# 8                                                                                                           mentions high or unexpected prices for food or drinks
# 9                                                                                                          mentions long wait times for seating, food, or service
# 17                                                    describes safety concerns or warnings, such as issues with spicy food, unsafe bathrooms, or drink tampering
# 1                                                                                     mentions that the food is mediocre or has flaws in preparation or freshness
# 11                                                                mentions unhygienic conditions in the restaurant, such as filth, grease, or lack of cleanliness
# 15                                                                    mentions issues or complaints about restaurant policies, services, or operational practices
# 13                                                                mentions experiences of food causing illness, such as food poisoning, stomach pain, or vomiting
# 12                                                             mentions lack of availability or inadequacy of food, beverages, or services advertised or expected
# 18       mentions dissatisfaction with specific aspects of a venue or service, often with detailed complaints about cleanliness, maintenance, or customer service
# 5                                                        mentions issues with incorrect or missing food orders, often involving unhelpful or rude staff responses
# 4                                                                                       mentions dissatisfaction with restaurant policies or management practices
# 0                                                                                                                   complains about poor or rude customer service
# 6                                                          complains about repeated service errors or unresolved issues despite multiple attempts to address them
# 16                        mentions negative or critical commentary about the restaurant's atmosphere, food quality, or service in a sarcastic or exaggerated tone
#
#     separation_score  separation_pval  regression_coef  regression_pval  \
# 7              2.012              0.0            0.490            0.000
# 14             1.494              0.0            0.215            0.000
# 2              1.409              0.0            0.043            0.036
# 10             1.114              0.0            0.106            0.000
# 19             1.072              0.0            0.002            0.960
# 3              0.245              0.0            0.032            0.085
# 8             -0.971              0.0           -0.082            0.000
# 9             -1.280              0.0            0.060            0.008
# 17            -1.861              0.0           -0.142            0.001
# 1             -1.925              0.0           -0.167            0.000
# 11            -2.043              0.0           -0.110            0.005
# 15            -2.074              0.0           -0.164            0.000
# 13            -2.109              0.0           -0.244            0.000
# 12            -2.192              0.0           -0.092            0.003
# 18            -2.271              0.0           -0.222            0.000
# 5             -2.351              0.0           -0.127            0.000
# 4             -2.408              0.0           -0.217            0.000
# 0             -2.436              0.0           -0.418            0.000
# 6             -2.459              0.0           -0.371            0.000
# 16            -2.465              0.0           -0.730            0.000
#
#     feature_prevalence
# 7                0.611
# 14               0.350
# 2                0.368
# 10               0.177
# 19               0.122
# 3                0.169
# 8                0.110
# 9                0.132
# 17               0.040
# 1                0.284
# 11               0.041
# 15               0.400
# 13               0.014
# 12               0.338
# 18               0.362
# 5                0.154
# 4                0.294
# 0                0.241
# 6                0.151
# 16               0.306
# R^2: 0.776
# Significant hypotheses: 16/20 (p < 5.000e-03)

# %% [markdown]
# ### Top sampling (instead of percentile sampling)

# %%
task_specific_instructions = """All of the texts are reviews of restaurants on Yelp.
Features should describe a specific aspect of the review. For example:
- "mentions long wait times to receive service"
- "praises how a dish was cooked, with phrases like 'perfect medium-rare'\""""

hypotheses_df = generate_hypotheses(
    texts=train_texts,
    labels=train_labels,
    embeddings=train_embeddings,
    sae=sae_1024_32,
    cache_name=CACHE_NAME,
    classification=False,
    selection_method="lasso",
    n_selected_neurons=20,
    interpreter_model="gpt-4o",
    annotator_model="gpt-4o-mini",
    n_examples_for_interpretation=20,
    max_words_per_example=128,
    interpret_temperature=0.7,
    max_interpretation_tokens=100,
    n_candidate_interpretations=3,
    n_scoring_examples=200,
    scoring_metric="f1",
    n_workers_interpretation=10,
    n_workers_annotation=50, 
    task_specific_instructions=task_specific_instructions,
)

pd.set_option('display.max_colwidth', None)
display(hypotheses_df.sort_values(by='target_lasso', ascending=False))
pd.reset_option('display.max_colwidth')
# Out:
# Embeddings shape: (200000, 1536)
# Activations shape (from 1 SAEs): (200000, 1024)
#
# Step 1: Selecting top 20 predictive neurons
# LASSO iteration   L1 Alpha # Features   Time (s)
# ----------------------------------------
#        0   1.00e-01          5       3.78
#        1   3.16e-04        913       9.93
#        2   5.62e-03        197       4.89
#        3   2.37e-02         45       4.06
#        4   4.87e-02         12       3.81
#        5   3.40e-02         26       3.92
#        6   4.07e-02         19       3.90
#        7   3.72e-02         21       3.89
#        8   3.89e-02         19       3.89
#        9   3.80e-02         19       3.89
#       10   3.76e-02         19       3.90
#       11   3.74e-02         21       3.91
#       12   3.75e-02         20       3.92
#
# Found alpha=3.75e-02 yielding exactly 20 features
# Total search time: 57.70s
#
# Step 2: Interpreting selected neurons
# Generating 3 interpretation(s) per neuron:   0%|          | 0/60 [00:00<?, ?it/s]
# Step 3: Scoring Interpretations
# Found 0 cached items; annotating 12000 uncached items
# Scoring neuron interpretation fidelity (20 neurons; 3 candidate interps per neuron; 200 examples to score each…
# API timeout, retrying in 1.0s... (1/3)
#     neuron_idx  source_sae  target_lasso  \
# 2          767  (1024, 32)      0.077037
# 7          313  (1024, 32)      0.023009
# 10           4  (1024, 32)      0.009572
# 14         554  (1024, 32)      0.005992
# 19         262  (1024, 32)      0.000053
# 18          21  (1024, 32)     -0.002484
# 17         840  (1024, 32)     -0.003030
# 16         763  (1024, 32)     -0.003443
# 15         864  (1024, 32)     -0.003551
# 13         941  (1024, 32)     -0.006590
# 12         122  (1024, 32)     -0.008083
# 11         900  (1024, 32)     -0.008381
# 9          329  (1024, 32)     -0.012144
# 8          305  (1024, 32)     -0.013403
# 6          340  (1024, 32)     -0.025866
# 5          380  (1024, 32)     -0.041503
# 4          158  (1024, 32)     -0.050918
# 3          412  (1024, 32)     -0.072424
# 1          641  (1024, 32)     -0.078028
# 0          914  (1024, 32)     -1.114304
#
#                                                                                                                                                  interpretation  \
# 2                                                                        expresses awe or admiration for the chef's artistry and creativity in food preparation
# 7                                                                                         explicitly praises both the food and the service in a positive manner
# 10                                                                               uses the phrase 'the best' to describe food, drinks, or the overall experience
# 14                                                                            uses exaggerated enthusiasm with repeated letters, punctuation, or capitalization
# 19  repeatedly emphasizes that the restaurant or dish is the 'best' in a specific category or area, often using phrases like 'hands down' or 'without question'
# 18                                               mentions experiences or reviews related to industries outside of food, such as car services, museums, or tours
# 17                                                                                     mentions safety concerns or hazards related to the restaurant experience
# 16                               describes a place or food as being 'exactly what it is' or 'what you expect', often emphasizing mediocrity or lack of surprise
# 15                                                               mentions issues or inconsistencies with restaurant hours, location, or availability of service
# 13                                                                       describes experiencing food poisoning or severe illness after eating at the restaurant
# 12                                                   mentions lack of availability or absence of expected items (e.g., food, utensils, ingredients, or seating)
# 11                                                                                                       mentions unsanitary food handling or hygiene practices
# 9                                                                                                          mentions long wait times for seating or food service
# 8                                                                                            mentions complaints about high or hidden prices for food or drinks
# 6                                                                                                               complains about slow service or long wait times
# 5                            mentions an issue with the order or service and describes a lack of or inadequate response from the restaurant staff or management
# 4                                               mentions a specific policy or rule enforced by the restaurant that negatively affects the customer's experience
# 3                                                                                                             mentions quick or convenient service/food options
# 1                       expresses lukewarm or mixed feelings about the overall experience, often mentioning that it is 'okay', 'solid', or 'good but not great'
# 0                                                    describes extremely poor service, including rudeness, unhelpful staff, or long delays in receiving service
#
#     f1_fidelity_score
# 2            0.904751
# 7            0.722207
# 10           0.933690
# 14           0.874743
# 19           0.984772
# 18           0.496241
# 17           0.939574
# 16           0.647887
# 15           0.590840
# 13           0.994975
# 12           0.896000
# 11           0.974974
# 9            0.969897
# 8            0.989899
# 6            0.839524
# 5            0.914317
# 4            0.959896
# 3            0.670588
# 1            0.942857
# 0            0.969072

# %%
np.random.seed(42)
holdout_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "holdout-50K.json"), lines=True)
holdout_sample_size = 10000
holdout_indices = np.random.choice(len(holdout_df), size=holdout_sample_size, replace=False)
holdout_sample = holdout_df.iloc[holdout_indices]

holdout_texts = holdout_sample[text_col].tolist()
holdout_labels = holdout_sample[label_col].values

metrics, hypothesis_df = evaluate_hypotheses(
    hypotheses_df=hypotheses_df,
    texts=holdout_texts,
    labels=holdout_labels,
    cache_name=CACHE_NAME,
    classification=False,
    n_workers_annotation=50,
)

pd.set_option('display.max_colwidth', None)
display(hypothesis_df.round(3).sort_values(by='separation_score', ascending=False))
pd.reset_option('display.max_colwidth')

print(f"R^2: {metrics['r2']:.3f}")
print(f"Significant hypotheses: {metrics['Significant'][0]}/{metrics['Significant'][1]} " 
      f"(p < {metrics['Significant'][2]:.3e})")
# Out:
# Step 1: Annotating texts with 20 hypotheses
# Found 200000 cached items; annotating 0 uncached items
# Step 2: Computing predictiveness of hypothesis annotations
#                                                                                                                                                      hypothesis  \
# 7                                                                                         explicitly praises both the food and the service in a positive manner
# 2                                                                        expresses awe or admiration for the chef's artistry and creativity in food preparation
# 19  repeatedly emphasizes that the restaurant or dish is the 'best' in a specific category or area, often using phrases like 'hands down' or 'without question'
# 10                                                                               uses the phrase 'the best' to describe food, drinks, or the overall experience
# 14                                                                            uses exaggerated enthusiasm with repeated letters, punctuation, or capitalization
# 3                                                                                                             mentions quick or convenient service/food options
# 18                                               mentions experiences or reviews related to industries outside of food, such as car services, museums, or tours
# 1                       expresses lukewarm or mixed feelings about the overall experience, often mentioning that it is 'okay', 'solid', or 'good but not great'
# 16                               describes a place or food as being 'exactly what it is' or 'what you expect', often emphasizing mediocrity or lack of surprise
# 9                                                                                                          mentions long wait times for seating or food service
# 8                                                                                            mentions complaints about high or hidden prices for food or drinks
# 15                                                               mentions issues or inconsistencies with restaurant hours, location, or availability of service
# 17                                                                                     mentions safety concerns or hazards related to the restaurant experience
# 12                                                   mentions lack of availability or absence of expected items (e.g., food, utensils, ingredients, or seating)
# 6                                                                                                               complains about slow service or long wait times
# 4                                               mentions a specific policy or rule enforced by the restaurant that negatively affects the customer's experience
# 11                                                                                                       mentions unsanitary food handling or hygiene practices
# 13                                                                       describes experiencing food poisoning or severe illness after eating at the restaurant
# 5                            mentions an issue with the order or service and describes a lack of or inadequate response from the restaurant staff or management
# 0                                                    describes extremely poor service, including rudeness, unhelpful staff, or long delays in receiving service
#
#     separation_score  separation_pval  regression_coef  regression_pval  \
# 7              1.862            0.000            0.702            0.000
# 2              1.292            0.000            0.221            0.000
# 19             1.107            0.000            0.164            0.000
# 10             1.056            0.000            0.055            0.066
# 14             0.989            0.000            0.160            0.000
# 3              0.966            0.000            0.107            0.000
# 18            -0.052            0.821            0.360            0.005
# 1             -0.805            0.000            0.021            0.316
# 16            -1.032            0.000           -0.429            0.000
# 9             -1.339            0.000            0.077            0.021
# 8             -1.340            0.000           -0.301            0.000
# 15            -1.479            0.000            0.045            0.089
# 17            -1.625            0.000           -0.149            0.000
# 12            -1.780            0.000           -0.225            0.000
# 6             -1.887            0.000            0.103            0.004
# 4             -1.980            0.000           -0.159            0.000
# 11            -2.130            0.000           -0.203            0.000
# 13            -2.328            0.000           -0.558            0.000
# 5             -2.352            0.000           -0.798            0.000
# 0             -2.546            0.000           -1.079            0.000
#
#     feature_prevalence
# 7                0.526
# 2                0.246
# 19               0.100
# 10               0.166
# 14               0.235
# 3                0.246
# 18               0.004
# 1                0.262
# 16               0.063
# 9                0.119
# 8                0.122
# 15               0.164
# 17               0.068
# 12               0.192
# 6                0.188
# 4                0.102
# 11               0.053
# 13               0.008
# 5                0.256
# 0                0.180
# R^2: 0.706
# Significant hypotheses: 16/20 (p < 5.000e-03)

# %% [markdown]
# ## Congress

# %%
DATASET_NAME = "congress"
EMBEDDER = "text-embedding-3-small"
CACHE_NAME = f"{DATASET_NAME}_{EMBEDDER}"

text_col = "speech_text"
label_col = "republican"
train_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "train-10sentence-114K.json"), lines=True)
val_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "val-10sentence-16K.json"), lines=True)

train_texts = train_df[text_col].tolist()
val_texts = val_df[text_col].tolist()

train_labels = train_df[label_col].values

text2embedding = get_openai_embeddings(train_texts + val_texts, model=EMBEDDER, cache_name=CACHE_NAME)

train_embeddings = np.stack([text2embedding[text] for text in train_texts])
val_embeddings = np.stack([text2embedding[text] for text in val_texts])
# Out:
# Loading embedding chunks:   0%|          | 0/3 [00:00<?, ?it/s]
# Loaded 130765 embeddings in 13.9s

# %%
checkpoint_dir = f"./checkpoints/{CACHE_NAME}"
sae_4096_32 = train_sae(embeddings=train_embeddings, M=4096, K=32, checkpoint_dir=checkpoint_dir, val_embeddings=val_embeddings)

activations = sae_4096_32.get_activations(train_embeddings)

selected_neurons, scores = select_neurons(
    activations=activations,
    target=train_labels,
    n_select=20,
    method="lasso",
    classification=True,
    verbose=True,
)
# Out:
# Loaded model from ./checkpoints/congress_text-embedding-3-small/SAE_M=4096_K=32.pt
# LASSO iteration   L1 Alpha # Features   Time (s)
# ----------------------------------------
#        0   1.00e-01       4093     134.15
#        1   3.16e+01       3730      65.72
#        2   5.62e+02        691      37.53
#        3   2.37e+03         30      28.27
#        4   4.87e+03          4      23.47
#        5   3.40e+03         16      27.70
#        6   2.84e+03         21      28.88
#        7   3.11e+03         18      28.89
#        8   2.97e+03         20      28.75
#
# Found alpha=2.97e+03 yielding exactly 20 features
# Total search time: 403.37s

# %%
interpreter = NeuronInterpreter(
    interpreter_model="gpt-4o",
    annotator_model="gpt-4o-mini",
    n_workers_annotation=50,
    cache_name=CACHE_NAME,
)

interpretation_sampling_config = SamplingConfig(
    function=sample_percentile_bins,
    n_examples=20,
    extra_kwargs={
        "high_percentile": (90, 100),
        "low_percentile": None, # Randomly samples from zero-activating examples
    },
)

interpret_config = InterpretConfig(
    sampling=interpretation_sampling_config,
    n_candidates=3,
    task_specific_instructions = """All of the texts are excerpts of speeches from the US Congress.
Example features may include:
- "mentions that the economy is strong"
- "discusses environmental issues or environmental policy\""""
)

interpretations = interpreter.interpret_neurons(
    texts=train_texts,
    activations=activations,
    neuron_indices=selected_neurons,
    config=interpret_config,
)

scoring_config = ScoringConfig(
    n_examples=200,
    sampling_function=sample_percentile_bins,
    sampling_kwargs={
        "high_percentile": (90, 100),
        "low_percentile": None, # Randomly samples from zero-activating examples
    },
)

all_metrics = interpreter.score_interpretations(
    texts=train_texts,
    activations=activations,
    interpretations=interpretations,
    config=scoring_config,
)
# Out:
# Generating 3 interpretation(s) per neuron:   0%|          | 0/60 [00:00<?, ?it/s]
# Warning: There are less than 100 examples in (90, 100) for neuron 681; using 90 instead
# Found 0 cached items; annotating 11970 uncached items
# Scoring neuron interpretation fidelity (20 neurons; 3 candidate interps per neuron; 200 examples to score each…

# %%
results = []
for neuron_idx, fidelity_scores in all_metrics.items():
    best_interp = max(interpretations[neuron_idx], key=lambda interp: fidelity_scores[interp]['f1'])
    results.append({
        'neuron_idx': neuron_idx,
        'target_lasso_coef': scores[selected_neurons.index(neuron_idx)],
        'interpretation': best_interp,
        'f1_fidelity_score': fidelity_scores[best_interp]['f1'],
    })

interpretation_df = pd.DataFrame(results)
pd.set_option('display.max_colwidth', None)
display(interpretation_df.sort_values(by='target_lasso_coef', ascending=False))
pd.reset_option('display.max_colwidth')
# Out:
#     neuron_idx  target_lasso_coef  \
# 3         1369           0.060833
# 5         3380           0.049250
# 8         3394           0.037155
# 12        1296           0.015483
# 14        2102           0.011286
# 15         681           0.009446
# 17        1351           0.004072
# 18        1268           0.000823
# 19        1314           0.000232
# 16        1951          -0.009246
# 13         645          -0.014326
# 11        1087          -0.015784
# 10        2972          -0.019883
# 9         2864          -0.024828
# 7         3585          -0.038804
# 6         1559          -0.044122
# 4          658          -0.051080
# 2         3547          -0.073418
# 1         2243          -0.122145
# 0         2637          -0.183849
#
#                                                                                                                                          interpretation  \
# 3                                                                                                             uses the phrase 'I ask unanimous consent'
# 5                                                                               describes the Senate schedule or legislative agenda for the day or week
# 8                                                                                                 mentions positive economic indicators or achievements
# 12                                                                                                      discusses illegal immigration or related issues
# 14                                                       requests unanimous consent for a committee or subcommittee to meet on a specific date and time
# 15  requests unanimous consent for Senate committees or subcommittees to meet during the session of the Senate to receive testimony or conduct hearings
# 17                                                                   mentions bills, resolutions, or amendments with specific section or clause numbers
# 18                                                                              discusses economic growth, including rates, impacts, or related metrics
# 19                                                                                    discusses government spending, deficits, or fiscal responsibility
# 16                                                                                                        mentions poverty or issues related to poverty
# 13                                                                          criticizes tax policies or cuts that benefit the wealthy disproportionately
# 11                              criticizes policies or actions that favor the wealthy or special interests over working-class or middle-class Americans
# 10                                                                                                             mentions or critiques the administration
# 9                                                                                                      criticizes government inefficiency or corruption
# 7                                                                                    mentions the national debt or fiscal policy issues related to debt
# 6                                                                                                        discusses budget cuts or reductions in funding
# 4                                                           discusses topics related to African American history or racial justice in the United States
# 2                                                                                                        opposes or critiques legislation or amendments
# 1                                                                                                         criticizes Republicans or Republican policies
# 0                                         criticizes the actions or inactions of the government or administration in handling specific issues or crises
#
#     f1_fidelity_score
# 3            0.984772
# 5            0.974359
# 8            0.448594
# 12           0.949579
# 14           0.936170
# 15           1.000000
# 17           0.736561
# 18           0.878644
# 19           0.959896
# 16           0.959583
# 13           0.959583
# 11           0.868966
# 10           0.808970
# 9            0.806914
# 7            0.994975
# 6            0.894556
# 4            1.000000
# 2            0.850581
# 1            0.914317
# 0            0.799515

# %%
np.random.seed(42)
holdout_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "holdout-10sentence-onechunk-12K.json"), lines=True)
holdout_texts = holdout_df[text_col].tolist()
holdout_labels = holdout_df[label_col].values

metrics, hypothesis_df = evaluate_hypotheses(
    hypotheses_df=interpretation_df,
    texts=holdout_texts,
    labels=holdout_labels,
    cache_name=CACHE_NAME,
    classification=True,
    n_workers_annotation=50,
)

pd.set_option('display.max_colwidth', None)
display(hypothesis_df.round(3).sort_values(by='separation_score', ascending=False))
pd.reset_option('display.max_colwidth')

print(f"AUC: {metrics['auroc']:.3f}")
print(f"Pseudo R^2: {metrics['r2']:.3f}")
print(f"Significant hypotheses: {metrics['Significant'][0]}/{metrics['Significant'][1]} " 
      f"(p < {metrics['Significant'][2]:.3e})")
# Out:
# Step 1: Annotating texts with 20 hypotheses
# Found 251600 cached items; annotating 0 uncached items
# Step 2: Computing predictiveness of hypothesis annotations
# Optimization terminated successfully.
#          Current function value: 0.611921
#          Iterations 7
#                                                                                                                                              hypothesis  \
# 14                                                       requests unanimous consent for a committee or subcommittee to meet on a specific date and time
# 15  requests unanimous consent for Senate committees or subcommittees to meet during the session of the Senate to receive testimony or conduct hearings
# 5                                                                               describes the Senate schedule or legislative agenda for the day or week
# 3                                                                                                             uses the phrase 'I ask unanimous consent'
# 17                                                                   mentions bills, resolutions, or amendments with specific section or clause numbers
# 8                                                                                                 mentions positive economic indicators or achievements
# 12                                                                                                      discusses illegal immigration or related issues
# 18                                                                              discusses economic growth, including rates, impacts, or related metrics
# 19                                                                                    discusses government spending, deficits, or fiscal responsibility
# 6                                                                                                        discusses budget cuts or reductions in funding
# 4                                                           discusses topics related to African American history or racial justice in the United States
# 7                                                                                    mentions the national debt or fiscal policy issues related to debt
# 2                                                                                                        opposes or critiques legislation or amendments
# 16                                                                                                        mentions poverty or issues related to poverty
# 10                                                                                                             mentions or critiques the administration
# 0                                         criticizes the actions or inactions of the government or administration in handling specific issues or crises
# 9                                                                                                      criticizes government inefficiency or corruption
# 11                              criticizes policies or actions that favor the wealthy or special interests over working-class or middle-class Americans
# 13                                                                          criticizes tax policies or cuts that benefit the wealthy disproportionately
# 1                                                                                                         criticizes Republicans or Republican policies
#
#     separation_score  separation_pval  regression_coef  regression_pval  \
# 14             0.402              0.0            0.861            0.000
# 15             0.335              0.0           -0.077            0.677
# 5              0.300              0.0            0.648            0.000
# 3              0.296              0.0            0.463            0.000
# 17             0.159              0.0            0.322            0.000
# 8              0.129              0.0            0.277            0.002
# 12             0.127              0.0            0.877            0.000
# 18            -0.074              0.0            0.232            0.010
# 19            -0.124              0.0            0.355            0.000
# 6             -0.174              0.0           -0.000            0.998
# 4             -0.213              0.0           -0.743            0.000
# 7             -0.219              0.0           -0.389            0.001
# 2             -0.219              0.0            0.182            0.001
# 16            -0.258              0.0           -0.367            0.000
# 10            -0.260              0.0           -0.100            0.104
# 0             -0.289              0.0           -0.585            0.000
# 9             -0.313              0.0           -0.316            0.000
# 11            -0.390              0.0           -0.680            0.000
# 13            -0.417              0.0           -0.456            0.039
# 1             -0.417              0.0           -1.229            0.000
#
#     feature_prevalence
# 14               0.031
# 15               0.033
# 5                0.073
# 3                0.065
# 17               0.057
# 8                0.056
# 12               0.035
# 18               0.074
# 19               0.179
# 6                0.080
# 4                0.027
# 7                0.045
# 2                0.348
# 16               0.084
# 10               0.312
# 0                0.382
# 9                0.258
# 11               0.104
# 13               0.031
# 1                0.120
# AUC: 0.703
# Pseudo R^2: 0.116
# Significant hypotheses: 15/20 (p < 5.000e-03)

# %% [markdown]
# ### Top sampling (instead of percentile sampling)

# %%
task_specific_instructions = """All of the texts are excerpts of speeches from the US Congress.
Example features may include:
- "mentions that the economy is strong"
- "discusses environmental issues or environmental policy\""""

hypotheses_df = generate_hypotheses(
    texts=train_texts,
    labels=train_labels,
    embeddings=train_embeddings,
    sae=sae_4096_32,
    cache_name=CACHE_NAME,
    classification=True,
    selection_method="lasso",
    n_selected_neurons=20,
    interpreter_model="gpt-4o",
    annotator_model="gpt-4o-mini",
    n_examples_for_interpretation=20,
    max_words_per_example=128,
    interpret_temperature=0.7,
    max_interpretation_tokens=100,
    n_candidate_interpretations=3,
    n_scoring_examples=200,
    scoring_metric="f1",
    n_workers_interpretation=10,
    n_workers_annotation=50, 
    task_specific_instructions=task_specific_instructions,
)

pd.set_option('display.max_colwidth', None)
display(hypotheses_df.sort_values(by='target_lasso', ascending=False))
pd.reset_option('display.max_colwidth')

# %%
np.random.seed(42)
holdout_df = pd.read_json(os.path.join(base_dir, DATASET_NAME, "holdout-10sentence-onechunk-12K.json"), lines=True)
# holdout_sample_size = len(holdout_df)
# holdout_indices = np.random.choice(len(holdout_df), size=holdout_sample_size, replace=False)
# holdout_sample = holdout_df.iloc[holdout_indices]
holdout_texts = holdout_df[text_col].tolist()
holdout_labels = holdout_df[label_col].values

metrics, hypothesis_df = evaluate_hypotheses(
    hypotheses_df=hypotheses_df,
    texts=holdout_texts,
    labels=holdout_labels,
    cache_name=CACHE_NAME,
    classification=True,
    n_workers_annotation=50,
)

pd.set_option('display.max_colwidth', None)
display(hypothesis_df.round(3).sort_values(by='separation_score', ascending=False))
pd.reset_option('display.max_colwidth')

print(f"AUC: {metrics['auroc']:.3f}")
print(f"Significant hypotheses: {metrics['Significant'][0]}/{metrics['Significant'][1]} " 
      f"(p < {metrics['Significant'][2]:.3e})")
# Out:
# Step 1: Annotating texts with 20 hypotheses
# Found 10000 cached items; annotating 0 uncached items
# Step 2: Computing predictiveness of hypothesis annotations
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.575682
#          Iterations: 35
# /share/pierson/conda_virtualenvs/rm868_conda_envs/llm/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                                                                                                          hypothesis  \
# 15                                                                                      mentions specific times or hours of the day
# 4                                                                                     contains the phrase 'I ask unanimous consent'
# 11                                                                           mentions a specific time of day or schedule for events
# 12                                                                               mentions illegal immigration or illegal immigrants
# 5                                                              discusses tax cuts or reduced taxation as a means of economic growth
# 6                                              mentions members of the Republican Study Committee or Republican politicians by name
# 8   frequent use of numerical values, especially large dollar amounts, percentages, or time spans related to budget cuts or funding
# 1                                                                        mentions issues related to health care or health insurance
# 17                                                                 mentions African American contributions, achievements, or issues
# 13                                                                                                 urges opposition to an amendment
# 16                                                                     mentions military actions or operations related to terrorism
# 18                                           repeatedly mentions the concept of an 'enemy' in a militaristic or ideological context
# 2                                                                explicitly expresses opposition to a bill, resolution, or proposal
# 19                      mentions rising costs of living or economic challenges (e.g., healthcare costs, gas prices, tuition, wages)
# 14                                                                           mentions wealth inequality or tax cuts for the wealthy
# 9                                                          criticizes corporations or industries for unethical or harmful practices
# 10                                                                                 mentions the national debt or related statistics
# 0                                                   criticizes Congress or its leadership for inaction or failure to address issues
# 7                                                                                                mentions the word 'administration'
# 3                                                                         mentions Republicans multiple times in a negative context
#
#     separation_score  separation_pval  regression_coef  regression_pval  \
# 15             0.336            0.002            1.517            0.077
# 4              0.218            0.008            0.270            0.476
# 11             0.184            0.032           -0.182            0.758
# 12             0.060            0.809           -0.030            0.977
# 5             -0.041            0.752            0.558            0.459
# 6             -0.078            0.607           -0.340            0.637
# 8             -0.165            0.015            0.426            0.273
# 1             -0.171            0.011           -0.667            0.060
# 17            -0.192            0.443           -1.008            0.399
# 13            -0.201            0.001            0.368            0.542
# 16            -0.210            0.005           -0.746            0.055
# 18            -0.242            0.278           -0.581            0.642
# 2             -0.258            0.000           -0.272            0.637
# 19            -0.262            0.000           -0.311            0.493
# 14            -0.325            0.010           -0.764            0.455
# 9             -0.367            0.000           -0.987            0.026
# 10            -0.373            0.007           -1.378            0.242
# 0             -0.373            0.000           -1.122            0.000
# 7             -0.403            0.000           -2.328            0.002
# 3             -0.460            0.000          -23.564            1.000
#
#     feature_prevalence
# 15               0.042
# 4                0.078
# 11               0.072
# 12               0.008
# 5                0.030
# 6                0.022
# 8                0.122
# 1                0.124
# 17               0.008
# 13               0.162
# 16               0.096
# 18               0.010
# 2                0.218
# 19               0.098
# 14               0.032
# 9                0.132
# 10               0.026
# 0                0.250
# 7                0.064
# 3                0.044
# Holdout Set Metrics:
# AUC: 0.744
# Significant hypotheses: 2/20 (p < 5.000e-03)
